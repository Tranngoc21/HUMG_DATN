# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Data/data_preprocessing.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             Precipitation  Temperature  Relative Humidity  Wind Speed
# Date
# 1985-01-01            0.0        24.12              66.46       26.87
# 1985-01-02            0.0        24.27              66.08       26.60
# 1985-01-03            0.1        25.02              61.42       22.44
# 1985-01-04            0.2        25.26              60.54       22.89
# 1985-01-05            0.0        25.05              59.92       24.88

# %%
# Sắp xếp và kiểm tra dữ liệu
df = df.sort_index()

# kiểm tra liên tục thời gian
print(df.index.to_series().diff().value_counts().head())
# Out:
# Date
# 1 days    12204
# Name: count, dtype: int64

# %%
# Chọn biến đầu vào & mục tiêu
features = ['Precipitation', 'Relative Humidity', 'Wind Speed']
target = 'Temperature'

X = df[features]
y = df[target]

# %%
# Chia tập dữ liệu: 70% train, 15% validation, 15% test
total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size + val_size]
y_val = y[train_size:train_size + val_size]

X_test = X[train_size + val_size:]
y_test = y[train_size + val_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (8543, 3)
# y_train shape: (8543,)
# X_val shape: (1830, 3)
# y_val shape: (1830,)
# X_test shape: (1832, 3)
# y_test shape: (1832,)

# %%
# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled   = scaler_X.transform(X_val)
X_test_scaled  = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.values.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1,1))

# %%
# Hàm tạo chuỗi dữ liệu > Dự đoán ngày tiếp theo
def create_sequences(X, y, time_step):
    X_seq, y_seq = [], []
    
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])
        
    return np.array(X_seq), np.array(y_seq)

# %%
# Xác định time_step = 30 
time_step = 30

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, time_step)
X_val_seq, y_val_seq     = create_sequences(X_val_scaled, y_val_scaled, time_step)
X_test_seq, y_test_seq   = create_sequences(X_test_scaled, y_test_scaled, time_step)

# %%
# Khai báo thư viện
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

# %%
# Khởi tạo lớp LTCCell 
from keras.saving import register_keras_serializable

@register_keras_serializable()
class LTCCell(layers.Layer):
    def __init__(self, units, **kwargs):
        super(LTCCell, self).__init__(**kwargs)
        self.units = units
    # Khai báo state_size & output_size
    @property
    def state_size(self): # Kích thước trạng thái ẩn
        return self.units
    @property
    def output_size(self): # Kích thước đầu ra
        return self.units
    # Tạo các tham số (weights)
    def build(self, input_shape):
        input_dim = int(input_shape[-1])
# Trọng số cho input
        self.W = self.add_weight(
            shape=(input_dim, self.units),
            initializer='glorot_uniform',
            trainable=True,
            name='kernel_W'
        )
# Trọng số hồi quy
        self.U = self.add_weight(
            shape=(self.units, self.units),
            initializer='orthogonal',
            trainable=True,
            name='recurrent_kernel_U'
        )
# Bias
        self.b = self.add_weight(
            shape=(self.units,),
            initializer='zeros',
            trainable=True,
            name='bias_b'
        )
# Tham số τ (time constant) 
# τ lớn → cập nhật chậm
# τ nhỏ → cập nhật nhanh
        self.tau = self.add_weight(
            shape=(self.units,),
            initializer='ones',
            trainable=True,
            name='time_constant_tau'
        )
# Hệ số khuếch đại
        self.gain = self.add_weight(
            shape=(self.units,),
            initializer='ones',
            trainable=True,
            name='gain'
        )
        super(LTCCell, self).build(input_shape)
        # Hàm cập nhật trạng thái (call)
    def call(self, inputs, states):
        prev_output = states[0] 
# Tính h = Wx + Uh + b
        h = tf.matmul(inputs, self.W) + tf.matmul(prev_output, self.U) + self.b
# Giới hạn τ để tránh giá trị quá lớn/nhỏ
        tau_clipped = tf.clip_by_value(self.tau, 0.1, 10.0)
# α = 1/τ
        alpha = 1.0 / tau_clipped
# Hàm kích hoạt
        activation = tf.tanh(self.gain * h)
# Công thức cập nhật động học liên tục
        output = (1 - alpha) * prev_output + alpha * activation
        return output, [output]

# %%
from tensorflow.keras.models import load_model
import os
import glob

# Tìm tất cả file .keras trong thư mục hiện tại và thư mục con
print("Đang tìm kiếm file model .keras...")
all_keras_files = glob.glob("**/*.keras", recursive=True)
print(f"\nCác file .keras tìm thấy ({len(all_keras_files)}):")
for f in all_keras_files:
    print(f"  - {f}")

# Mapping tên model với các pattern có thể có
model_patterns = {
    "cnn": ["*cnn*.keras", "*CNN*.keras"],
    "lstm": ["*lstm*.keras", "*LSTM*.keras"],
    "gru": ["*gru*.keras", "*GRU*.keras"],
    "lnn": ["*lnn*.keras", "*LNN*.keras", "*liquid*.keras"]
}

models = {}
found_models = {}

for model_name, patterns in model_patterns.items():
    for pattern in patterns:
        matching_files = glob.glob(pattern, recursive=False) + glob.glob(pattern, recursive=True)
        if matching_files:
            found_models[model_name] = matching_files[0]
            break

print(f"\n{'='*50}")
print("KẾT QUẢ TÌM KIẾM:")
print(f"{'='*50}")

# Kiểm tra xem có đủ model không
if len(found_models) < 4:
    print(f"⚠️  Chỉ tìm thấy {len(found_models)}/4 model:")
    for name, path in found_models.items():
        print(f"  ✓ {name.upper()}: {path}")
    missing = set(["cnn", "lstm", "gru", "lnn"]) - set(found_models.keys())
    print(f"\n❌ Thiếu các model: {', '.join([m.upper() for m in missing])}")
    print("\n💡 Bạn cần:")
    print("   1. Chạy các notebook huấn luyện (03.CNN_1D.ipynb, 04.GRU.ipynb,")
    print("      05.LSTM.ipynb, 06.LNN.ipynb) để tạo và lưu model")
    print("   2. Hoặc đặt các file .keras đã có vào thư mục hiện tại")
    raise FileNotFoundError(f"Thiếu {len(missing)} model. Cần huấn luyện và lưu model trước.")

# Load các model đã tìm thấy
print(f"✅ Tìm thấy đủ 4 model:")

# Load CNN
model_cnn = load_model(found_models["cnn"])
print(f"  ✓ CNN: {found_models['cnn']}")

# Load LSTM
model_lstm = load_model(found_models["lstm"])
print(f"  ✓ LSTM: {found_models['lstm']}")

# Load GRU
model_gru = load_model(found_models["gru"])
print(f"  ✓ GRU: {found_models['gru']}")

# Load LNN (cần custom_objects)
model_lnn = load_model(found_models["lnn"], custom_objects={"LTCCell": LTCCell})
print(f"  ✓ LNN: {found_models['lnn']}")

print(f"\n{'='*50}")
print("✅ Tất cả model đã được load thành công!")
print(f"{'='*50}")
# Out:
# Đang tìm kiếm file model .keras...
#
# Các file .keras tìm thấy (6):
#   - best_hybrid_model.keras
#   - best_lstm_model.keras
#   - best_model_lnn.keras
#   - best_module_gru.keras
#   - module_cnn_1d.keras
#   - module_gru.keras
#
# ==================================================
# KẾT QUẢ TÌM KIẾM:
# ==================================================
# ✅ Tìm thấy đủ 4 model:
#   ✓ CNN: module_cnn_1d.keras
#   ✓ LSTM: best_lstm_model.keras
#   ✓ GRU: best_module_gru.keras
#   ✓ LNN: best_model_lnn.keras
#
# ==================================================
# ✅ Tất cả model đã được load thành công!
# ==================================================

# %%
y_pred_cnn  = scaler_y.inverse_transform(model_cnn.predict(X_test_seq))
y_pred_lstm = scaler_y.inverse_transform(model_lstm.predict(X_test_seq))
y_pred_gru  = scaler_y.inverse_transform(model_gru.predict(X_test_seq))
y_pred_lnn  = scaler_y.inverse_transform(model_lnn.predict(X_test_seq))

y_test_original = scaler_y.inverse_transform(y_test_seq)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

def evaluate_model(y_true, y_pred):
    mse  = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return mse, rmse, mae, r2, mape

# %%
results = {}
results["CNN-1D"] = evaluate_model(y_test_original, y_pred_cnn)
results["LSTM"]   = evaluate_model(y_test_original, y_pred_lstm)
results["GRU"]    = evaluate_model(y_test_original, y_pred_gru)
results["LNN"]    = evaluate_model(y_test_original, y_pred_lnn)

# %%
comparison_df = pd.DataFrame(results, 
                             index=["MSE", "RMSE", "MAE", "R²", "MAPE (%)"]).T
comparison_df.round(2)
# Out:
#          MSE  RMSE   MAE    R²  MAPE (%)
# CNN-1D  1.33  1.15  0.89  0.50      3.37
# LSTM    1.17  1.08  0.82  0.56      3.13
# GRU     1.32  1.15  0.89  0.51      3.39
# LNN     1.23  1.11  0.85  0.54      3.21

# %%
comparison_df[["RMSE", "MAE"]].plot(kind="bar", figsize=(8,5))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,5))

ax = comparison_df[["RMSE", "MAE"]].plot(
    marker="o",
    linewidth=2
)

plt.title("So sánh hiệu năng các mô hình")
plt.ylabel("Sai số (°C)")
plt.xlabel("Mô hình")
plt.xticks(rotation=0)
plt.legend(title="Chỉ số")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
comparison_df.plot(
    kind="line",
    marker="o",
    figsize=(9,6)
)

plt.title("So sánh toàn bộ chỉ số đánh giá")
plt.grid(True)
plt.show()

# %%
#### Trực quan hóa kết quả dự đoán - So sánh Actual vs Predicted

# Lấy index thời gian cho tập test
test_index = df.index[-len(y_test_seq):]

# Vẽ biểu đồ so sánh cho tất cả mô hình (200 ngày đầu tiên của test set)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
axes = axes.flatten()

models_data = [
    ("CNN-1D", y_pred_cnn),
    ("LSTM", y_pred_lstm),
    ("GRU", y_pred_gru),
    ("LNN", y_pred_lnn)
]

for idx, (name, y_pred) in enumerate(models_data):
    ax = axes[idx]
    ax.plot(test_index[:200], y_test_original[:200], label='Thực tế', color='blue', linewidth=1.5)
    ax.plot(test_index[:200], y_pred[:200], label='Dự đoán', color='orange', linewidth=1.5, alpha=0.8)
    ax.set_title(f'{name} - So sánh thực tế vs dự đoán', fontsize=12)
    ax.set_xlabel('Thời gian')
    ax.set_ylabel('Nhiệt độ (°C)')
    ax.legend()
    ax.grid(True, alpha=0.3)

# Ẩn subplot thừa
axes[4].axis('off')
axes[5].axis('off')

plt.tight_layout()
plt.show()

# %%
#### Scatter plot - Ma trận tương quan dự đoán
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# fig, axes = plt.subplots(1,3, figsize=(10,5))
axes = axes.flatten()

models_data = [
    ("CNN-1D", y_pred_cnn, results["CNN-1D"][3]),
    ("LSTM", y_pred_lstm, results["LSTM"][3]),
    ("GRU", y_pred_gru, results["GRU"][3]),
    ("LNN", y_pred_lnn, results["LNN"][3])
]

for idx, (name, y_pred, r2) in enumerate(models_data):
    ax = axes[idx]
    ax.scatter(y_test_original, y_pred, alpha=0.5, s=10)
    
    # Vẽ đường y=x
    min_val = min(y_test_original.min(), y_pred.min())
    max_val = max(y_test_original.max(), y_pred.max())
    ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Đường lý tưởng (y=x)')
    
    ax.set_xlabel('Nhiệt độ thực tế (°C)')
    ax.set_ylabel('Nhiệt độ dự đoán (°C)')
    ax.set_title(f'{name} - Scatter plot (R² = {r2:.4f})')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
#### Phân tích sai số dự đoán (Residuals)
# fig, axes = plt.subplots(1,3, figsize=(10,5))
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

models_data = [
    ("CNN-1D", y_pred_cnn),
    ("LSTM", y_pred_lstm),
    ("GRU", y_pred_gru),
    ("LNN", y_pred_lnn)
]

for idx, (name, y_pred) in enumerate(models_data):
    ax = axes[idx]
    residuals = y_test_original - y_pred
    
    ax.hist(residuals.flatten(), bins=50, edgecolor='black', alpha=0.7)
    ax.axvline(x=0, color='r', linestyle='--', label='Sai số = 0')
    ax.set_xlabel('Sai số (°C)')
    ax.set_ylabel('Tần suất')
    ax.set_title(f'{name} - Phân bố sai số\nMean: {residuals.mean():.4f}°C, Std: {residuals.std():.4f}°C')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
#### So sánh tất cả mô hình trên cùng một biểu đồ

plt.figure(figsize=(14, 7))

# Vẽ đường thực tế
plt.plot(test_index[:200], y_test_original[:200], label='Thực tế', color='black', linewidth=2, linestyle='-', marker='o', markersize=3)

# Vẽ đường dự đoán của từng mô hình
plt.plot(test_index[:200], y_pred_lstm[:200], label='LSTM', color='blue', linewidth=1.5, alpha=0.8)
plt.plot(test_index[:200], y_pred_lnn[:200], label='LNN', color='green', linewidth=1.5, alpha=0.8)
plt.plot(test_index[:200], y_pred_cnn[:200], label='CNN-1D', color='red', linewidth=1.5, alpha=0.8)
plt.plot(test_index[:200], y_pred_gru[:200], label='GRU', color='purple', linewidth=1.5, alpha=0.8)

plt.title('So sánh tất cả mô hình - 200 ngày đầu tiên của tập test', fontsize=14)
plt.xlabel('Thời gian', fontsize=12)
plt.ylabel('Nhiệt độ (°C)', fontsize=12)
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# In bảng tổng hợp metrics
print("\n===== BẢNG TỔNG HỢP KẾT QUẢ ĐÁNH GIÁ =====")
comparison_df_display = comparison_df.copy()
comparison_df_display['MAPE (%)'] = comparison_df_display['MAPE (%)'].apply(lambda x: f"{x:.2f}%")
print(comparison_df_display.round(4))
# Out:
# ===== BẢNG TỔNG HỢP KẾT QUẢ ĐÁNH GIÁ =====
#            MSE    RMSE     MAE      R² MAPE (%)
# CNN-1D  1.3266  1.1518  0.8868  0.5031    3.37%
# LSTM    1.1727  1.0829  0.8175  0.5607    3.13%
# GRU     1.3168  1.1475  0.8944  0.5067    3.39%
# LNN     1.2332  1.1105  0.8469  0.5381    3.21%

# %%
# CNN
y_train_pred_cnn = model_cnn.predict(X_train_seq)
y_test_pred_cnn = model_cnn.predict(X_test_seq)

# LSTM
y_train_pred_lstm = model_lstm.predict(X_train_seq)
y_test_pred_lstm = model_lstm.predict(X_test_seq)

# GRU
y_train_pred_gru = model_gru.predict(X_train_seq)
y_test_pred_gru = model_gru.predict(X_test_seq)

# LNN
y_train_pred_lnn = model_lnn.predict(X_train_seq)
y_test_pred_lnn = model_lnn.predict(X_test_seq)
# Out:
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Actual values
y_train_actual = scaler_y.inverse_transform(y_train_seq)
y_test_actual  = scaler_y.inverse_transform(y_test_seq)

# CNN
y_train_pred_cnn = scaler_y.inverse_transform(y_train_pred_cnn)
y_test_pred_cnn  = scaler_y.inverse_transform(y_test_pred_cnn)

# LSTM
y_train_pred_lstm = scaler_y.inverse_transform(y_train_pred_lstm)
y_test_pred_lstm  = scaler_y.inverse_transform(y_test_pred_lstm)

# GRU
y_train_pred_gru = scaler_y.inverse_transform(y_train_pred_gru)
y_test_pred_gru  = scaler_y.inverse_transform(y_test_pred_gru)

# LNN
y_train_pred_lnn = scaler_y.inverse_transform(y_train_pred_lnn)
y_test_pred_lnn  = scaler_y.inverse_transform(y_test_pred_lnn)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2,2, figsize=(14,10))
axes = axes.flatten()

models = [
    ("CNN-1D", y_train_pred_cnn, y_test_pred_cnn),
    ("LSTM", y_train_pred_lstm, y_test_pred_lstm),
    ("GRU", y_train_pred_gru, y_test_pred_gru),
    ("LNN", y_train_pred_lnn, y_test_pred_lnn)
]

for i,(name,train_pred,test_pred) in enumerate(models):

    ax = axes[i]

    # Actual
    actual = np.concatenate((y_train_actual, y_test_actual)).flatten()

    # Train prediction
    train_plot = np.empty_like(actual)
    train_plot[:] = np.nan
    train_plot[:len(train_pred)] = train_pred.flatten()

    # Test prediction
    test_plot = np.empty_like(actual)
    test_plot[:] = np.nan
    test_plot[len(train_pred):len(train_pred)+len(test_pred)] = test_pred.flatten()

    ax.plot(actual, label="Actual", linewidth=2)
    ax.plot(train_plot, label="Train Prediction", linestyle="--")
    ax.plot(test_plot, label="Test Prediction", linestyle="--")

    ax.set_title(name)
    ax.set_xlabel("Time Step")
    ax.set_ylabel("Temperature (°C)")
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual data
actual = np.concatenate((y_train_actual, y_test_actual)).flatten()

models = [
    ("CNN-1D", y_train_pred_cnn, y_test_pred_cnn),
    ("LSTM", y_train_pred_lstm, y_test_pred_lstm),
    ("GRU", y_train_pred_gru, y_test_pred_gru),
    ("LNN", y_train_pred_lnn, y_test_pred_lnn)
]

for name, train_pred, test_pred in models:

    plt.figure(figsize=(12,5))

    train_pred = train_pred.flatten()
    test_pred = test_pred.flatten()

    train_plot = np.empty_like(actual)
    train_plot[:] = np.nan
    train_plot[:len(train_pred)] = train_pred

    test_plot = np.empty_like(actual)
    test_plot[:] = np.nan
    test_plot[len(train_pred):len(train_pred)+len(test_pred)] = test_pred

    plt.plot(actual, label="Actual", linewidth=2)
    plt.plot(train_plot, label="Train Prediction", linestyle="--")
    plt.plot(test_plot, label="Test Prediction", linestyle="--")

    plt.title(f"{name}: Actual vs Train vs Test Prediction")
    plt.xlabel("Time Step")
    plt.ylabel("Temperature (°C)")
    plt.legend()
    plt.grid(True)

    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

# dữ liệu thực
actual = np.concatenate((y_train_actual, y_test_actual)).flatten()

# tạo mảng prediction
train_plot = np.empty_like(actual)
train_plot[:] = np.nan
train_plot[:len(y_train_pred_lstm)] = y_train_pred_lstm.flatten()

test_plot = np.empty_like(actual)
test_plot[:] = np.nan
test_plot[len(y_train_pred_lstm):len(y_train_pred_lstm)+len(y_test_pred_lstm)] = y_test_pred_lstm.flatten()

# vẽ biểu đồ
plt.plot(actual, color='blue', label="Thực tế", linewidth=2)
plt.plot(train_plot, color='red', label="Dự báo tập huấn luyện", linewidth=2)
plt.plot(test_plot, color='green', label="Dự báo tập giám sát", linewidth=2)

plt.title("Biểu đồ so sánh giá trị thực tế và dự báo", fontsize=14)
plt.xlabel("Thời gian")
plt.ylabel("Nhiệt độ (°C)")
plt.legend()
plt.grid(True)

plt.show()

# %%
def predict_future(model, last_sequence, n_future, scaler_y):

    future_predictions = []
    current_seq = last_sequence.copy()

    n_features = current_seq.shape[1]

    for i in range(n_future):

        pred = model.predict(current_seq.reshape(1, current_seq.shape[0], n_features), verbose=0)
        future_predictions.append(pred[0,0])

        # tạo hàng mới cùng số feature
        new_row = np.zeros((1, n_features))

        # giả sử target nằm ở feature đầu tiên
        new_row[0,0] = pred[0,0]

        # cập nhật sequence
        current_seq = np.vstack((current_seq[1:], new_row))

    future_predictions = np.array(future_predictions).reshape(-1,1)
    future_predictions = scaler_y.inverse_transform(future_predictions)

    return future_predictions

# %%
last_sequence = X_test_seq[-1]
future_days = 50

# %%
future_cnn  = predict_future(model_cnn, last_sequence, future_days, scaler_y)
future_lstm = predict_future(model_lstm, last_sequence, future_days, scaler_y)
future_gru  = predict_future(model_gru, last_sequence, future_days, scaler_y)
future_lnn  = predict_future(model_lnn, last_sequence, future_days, scaler_y)
# future_hybrid = predict_future(model_hybrid, last_sequence, future_days, scaler_y)

# %%
def plot_future_trend(actual_data, future_pred, model_name):

    actual_50 = actual_data[-50:].flatten()

    trend = np.concatenate((actual_50, future_pred.flatten()))

    time_axis = np.arange(len(trend))

    plt.figure(figsize=(10,5))

    plt.plot(time_axis, trend, color='red', linewidth=2)

    plt.title(f"Biểu đồ xu hướng 50 ngày đầu và 50 ngày tiếp theo - {model_name}")
    plt.xlabel("Mốc thời gian")
    plt.ylabel("Giá trị")

    plt.grid(True)
    plt.show()

# %%
actual_data = scaler_y.inverse_transform(y_test_seq)

plot_future_trend(actual_data, future_cnn, "CNN-1D")
plot_future_trend(actual_data, future_lstm, "LSTM")
plot_future_trend(actual_data, future_gru, "GRU")
plot_future_trend(actual_data, future_lnn, "LNN")
# plot_future_trend(actual_data, future_hybrid, "Hybrid LNN-LSTM")
