# %%
import numpy as np
import pandas as pd
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras import layers

# %%
import tensorflow as tf
import random

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
df = pd.read_csv('Data/data_preprocessing.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             Precipitation  Temperature  Relative Humidity  Wind Speed
# Date
# 1985-01-01            0.0        24.12              66.46       26.87
# 1985-01-02            0.0        24.27              66.08       26.60
# 1985-01-03            0.1        25.02              61.42       22.44
# 1985-01-04            0.2        25.26              60.54       22.89
# 1985-01-05            0.0        25.05              59.92       24.88

# %%
# Sắp xếp và kiểm tra dữ liệu
df = df.sort_index()

# kiểm tra liên tục thời gian
print(df.index.to_series().diff().value_counts().head())
# Out:
# Date
# 1 days    12204
# Name: count, dtype: int64

# %%
# Chọn biến đầu vào & mục tiêu
features = ['Precipitation', 'Relative Humidity', 'Wind Speed']
target = 'Temperature'

X = df[features]
y = df[target]

# %%
# Chia tập dữ liệu: 70% train, 15% validation, 15% test
total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size + val_size]
y_val = y[train_size:train_size + val_size]

X_test = X[train_size + val_size:]
y_test = y[train_size + val_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (8543, 3)
# y_train shape: (8543,)
# X_val shape: (1830, 3)
# y_val shape: (1830,)
# X_test shape: (1832, 3)
# y_test shape: (1832,)

# %%
from sklearn.preprocessing import MinMaxScaler
# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled   = scaler_X.transform(X_val)
X_test_scaled  = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.values.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1,1))

# %%
# Hàm tạo chuỗi dữ liệu > Dự đoán ngày tiếp theo
def create_sequences(X, y, time_step):
    X_seq, y_seq = [], []
    
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])
        
    return np.array(X_seq), np.array(y_seq)

# %%
# Xác định time_step = 30 
time_step = 30

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, time_step)
X_val_seq, y_val_seq     = create_sequences(X_val_scaled, y_val_scaled, time_step)
X_test_seq, y_test_seq   = create_sequences(X_test_scaled, y_test_scaled, time_step)

# %%
X_train_seq = X_train_seq.reshape((X_train_seq.shape[0], X_train_seq.shape[1], X_train_seq.shape[2]))
X_val_seq   = X_val_seq.reshape((X_val_seq.shape[0], X_val_seq.shape[1], X_val_seq.shape[2]))

# %%
print(X_train_seq.shape)
print(X_val_seq.shape)
# Out:
# (8513, 30, 3)
# (1800, 30, 3)

# %%
# Khai báo thư viện
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras import layers

class LTCCell(layers.Layer):

    def __init__(self, units, **kwargs):
        super(LTCCell, self).__init__(**kwargs)
        self.units = units

    @property
    def state_size(self):
        return self.units

    @property
    def output_size(self):
        return self.units

    def build(self, input_shape):

        input_dim = input_shape[-1]

        self.W = self.add_weight(
            shape=(input_dim, self.units),
            initializer="glorot_uniform",
            name="W"
        )

        self.U = self.add_weight(
            shape=(self.units, self.units),
            initializer="orthogonal",
            name="U"
        )

        self.b = self.add_weight(
            shape=(self.units,),
            initializer="zeros",
            name="b"
        )

        self.tau = self.add_weight(
            shape=(self.units,),
            initializer="ones",
            name="tau"
        )

        self.gain = self.add_weight(
            shape=(self.units,),
            initializer="ones",
            name="gain"
        )

        super().build(input_shape)

    def call(self, inputs, states):

        prev_output = states[0]

        h = tf.matmul(inputs, self.W) + tf.matmul(prev_output, self.U) + self.b

        tau_clipped = tf.clip_by_value(self.tau, 0.1, 10.0)

        alpha = 1.0 / tau_clipped

        activation = tf.tanh(self.gain * h)

        output = (1 - alpha) * prev_output + alpha * activation

        return output, [output]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, RNN
from tensorflow.keras.optimizers import Adam
def build_hybrid_lstm_lnn(hp):

    lstm_units = hp.Choice("lstm_units", [16,32,64])
    lnn_units = hp.Choice("lnn_units", [16,32,64])
    lr = hp.Choice("learning_rate", [1e-3,5e-4])

    model = Sequential()

    model.add(Input(shape=(X_train_seq.shape[1], X_train_seq.shape[2])))

    model.add(
        LSTM(
            lstm_units,
            return_sequences=True
        )
    )

    model.add(
        RNN(
            LTCCell(lnn_units)
        )
    )

    model.add(Dense(1))

    model.compile(
        optimizer=Adam(lr),
        loss="mse",
        metrics=["mae"]
    )

    return model

# %%
import keras_tuner as kt

tuner_hybrid = kt.GridSearch(
    build_hybrid_lstm_lnn,
    objective="val_loss",
    executions_per_trial=1,
    overwrite=True,
    directory="hyperparameter_tuning",
    project_name="hybrid_lstm_lnn"
)

# %%
tuner_hybrid.search(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=20,
    batch_size=32,
    shuffle=False
)
# Out:
# Trial 18 Complete [00h 01m 44s]
# val_loss: 0.007763812318444252
#
# Best val_loss So Far: 0.0070586008951067924
# Total elapsed time: 00h 28m 37s

# %%
best_hps = tuner_hybrid.get_best_hyperparameters(num_trials=1)[0]
print("Best hyperparameters:")
print(best_hps.values)
# Out:
# Best hyperparameters:
# {'lstm_units': 16, 'lnn_units': 32, 'learning_rate': 0.001}

# %%
best_model_hybrid = tuner_hybrid.get_best_models(num_models=1)[0]
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
best_model_hybrid = tuner_hybrid.hypermodel.build(best_hps)

# %%
best_model_hybrid.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 30, 16)              │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rnn_1 (RNN)                          │ (None, 32)                  │           1,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,945 (11.50 KB)
#  Trainable params: 2,945 (11.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

# %%
history_hybrid = best_model_hybrid.fit(
    X_train_seq,
    y_train_seq,
    validation_data=(X_val_seq, y_val_seq),
    epochs=50,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - loss: 0.0236 - mae: 0.1130 - val_loss: 0.0094 - val_mae: 0.0763
# Epoch 2/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0116 - mae: 0.0848 - val_loss: 0.0080 - val_mae: 0.0705
# Epoch 3/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0076 - val_mae: 0.0693
# Epoch 4/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0098 - mae: 0.0776 - val_loss: 0.0074 - val_mae: 0.0685
# Epoch 5/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0096 - mae: 0.0764 - val_loss: 0.0073 - val_mae: 0.0682
# Epoch 6/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0094 - mae: 0.0758 - val_loss: 0.0073 - val_mae: 0.0681
# Epoch 7/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0093 - mae: 0.0753 - val_loss: 0.0073 - val_mae: 0.0678
# Epoch 8/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0071 - val_mae: 0.0668
# Epoch 9/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0091 - mae: 0.0745 - val_loss: 0.0068 - val_mae: 0.0648
# Epoch 10/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0091 - mae: 0.0742 - val_loss: 0.0066 - val_mae: 0.0636
# Epoch 11/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0090 - mae: 0.0740 - val_loss: 0.0066 - val_mae: 0.0635
# Epoch 12/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0089 - mae: 0.0736 - val_loss: 0.0067 - val_mae: 0.0642
# Epoch 13/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0088 - mae: 0.0731 - val_loss: 0.0069 - val_mae: 0.0653
# Epoch 14/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0087 - mae: 0.0728 - val_loss: 0.0070 - val_mae: 0.0658
# Epoch 15/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0087 - mae: 0.0725 - val_loss: 0.0073 - val_mae: 0.0671
# Epoch 16/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0086 - mae: 0.0723 - val_loss: 0.0073 - val_mae: 0.0667
# Epoch 17/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0086 - mae: 0.0721 - val_loss: 0.0074 - val_mae: 0.0672
# Epoch 18/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0085 - mae: 0.0719 - val_loss: 0.0074 - val_mae: 0.0676
# Epoch 19/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0085 - mae: 0.0717 - val_loss: 0.0075 - val_mae: 0.0678
# Epoch 20/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0084 - mae: 0.0715 - val_loss: 0.0075 - val_mae: 0.0680
# Epoch 21/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0084 - mae: 0.0714 - val_loss: 0.0076 - val_mae: 0.0682

# %%
y_pred_hybrid = best_model_hybrid.predict(X_test_seq)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
y_pred = scaler_y.inverse_transform(y_pred_hybrid)
y_test_original = scaler_y.inverse_transform(y_test_seq)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y_test_original, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred)
r2 = r2_score(y_test_original, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 1.084749839138012
# MAE: 0.8393675232780363
# R2: 0.5592193473354237

# %%
# Vẽ biểu đồ so sánh Thực tế vs Dự đoán
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test_original[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("So sánh nhiệt độ thực tế và dự đoán")
plt.show()

# %%
# Vẽ biểu đồ Loss trong quá trình train
plt.plot(history_hybrid.history['loss'], label='Train Loss')
plt.plot(history_hybrid.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training vs Validation Loss")
plt.show()

# %%
mape = np.mean(np.abs((y_test_original - y_pred) / y_test_original)) * 100
print(f"Sai số phần trăm trung bình (MAPE): {mape:.2f}%")
# Out:
# Sai số phần trăm trung bình (MAPE): 3.19%

# %%
accuracy = 100 - mape
print(f"Độ chính xác (Accuracy): {accuracy:.2f}%")
# Out:
# Độ chính xác (Accuracy): 96.81%

# %%
best_model_hybrid.save("best_hybrid_model.keras")
