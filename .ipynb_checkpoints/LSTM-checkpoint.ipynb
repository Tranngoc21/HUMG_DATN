# %%
# !pip install keras-tuner

# %%
import numpy as np
import pandas as pd
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras import layers

# %%
import tensorflow as tf
import random

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
df = pd.read_csv('Data/data_preprocessing.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             Precipitation  Temperature  Relative Humidity  Wind Speed
# Date
# 1985-01-01            0.0        24.12              66.46       26.87
# 1985-01-02            0.0        24.27              66.08       26.60
# 1985-01-03            0.1        25.02              61.42       22.44
# 1985-01-04            0.2        25.26              60.54       22.89
# 1985-01-05            0.0        25.05              59.92       24.88

# %%
# Sắp xếp và kiểm tra dữ liệu
df = df.sort_index()

# kiểm tra liên tục thời gian
print(df.index.to_series().diff().value_counts().head())
# Out:
# Date
# 1 days    12204
# Name: count, dtype: int64

# %%
# Chọn biến đầu vào & mục tiêu
features = ['Precipitation', 'Relative Humidity', 'Wind Speed']
target = 'Temperature'

X = df[features]
y = df[target]

# %%
# Chia tập dữ liệu: 70% train, 15% validation, 15% test
total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size + val_size]
y_val = y[train_size:train_size + val_size]

X_test = X[train_size + val_size:]
y_test = y[train_size + val_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (8543, 3)
# y_train shape: (8543,)
# X_val shape: (1830, 3)
# y_val shape: (1830,)
# X_test shape: (1832, 3)
# y_test shape: (1832,)

# %%
from sklearn.preprocessing import MinMaxScaler
# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled   = scaler_X.transform(X_val)
X_test_scaled  = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.values.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1,1))

# %%
# Hàm tạo chuỗi dữ liệu > Dự đoán ngày tiếp theo
def create_sequences(X, y, time_step):
    X_seq, y_seq = [], []
    
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])
        
    return np.array(X_seq), np.array(y_seq)

# %%
# Xác định time_step = 30 
time_step = 30

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, time_step)
X_val_seq, y_val_seq     = create_sequences(X_val_scaled, y_val_scaled, time_step)
X_test_seq, y_test_seq   = create_sequences(X_test_scaled, y_test_scaled, time_step)

# %%
# reshape cho LSTM
X_train_seq = X_train_seq.reshape((X_train_seq.shape[0], X_train_seq.shape[1], X_train_seq.shape[2]))
X_val_seq   = X_val_seq.reshape((X_val_seq.shape[0], X_val_seq.shape[1], X_val_seq.shape[2]))

# %%
print(X_train_seq.shape)
print(X_val_seq.shape)
# Out:
# (8513, 30, 3)
# (1800, 30, 3)

# %%
def build_lstm(hp):

    model = keras.Sequential([

        keras.Input(shape=(X_train_seq.shape[1], X_train_seq.shape[2])),

        layers.LSTM(
            hp.Int("lstm_units", 32, 128, step=32)
        ),

        layers.Dense(1)

    ])

    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Float("learning_rate", 1e-4, 1e-2, sampling="log")
        ),
        loss="mse",
        metrics=["mae"]
    )

    return model

# %%
# tuner_lstm = kt.RandomSearch(
#     build_lstm,
#     objective="val_loss",
#     max_trials=20,
#     executions_per_trial=1,
#     seed=42,
#     overwrite=True,
#     directory="hyperparameter_tuning",
#     project_name="lstm_search"
# )
tuner_lstm = kt.GridSearch(
    build_lstm,
    objective="val_loss",
    executions_per_trial=1,
    seed=42,
    overwrite=True,
    directory="hyperparameter_tuning",
    project_name="lstm_grid_search"
)

# %%
# tuner_lstm.search(
#     X_train_seq,
#     y_train_seq,
#     epochs=50,
#     validation_data=(X_val_seq, y_val_seq),
#     batch_size=32
# )
tuner_lstm.search(
    X_train_seq,
    y_train_seq,
    epochs=20,
    validation_data=(X_val_seq, y_val_seq),
    batch_size=32,
    shuffle=False
)
# Out:
# Trial 44 Complete [00h 01m 40s]
# val_loss: 0.008030502125620842
#
# Best val_loss So Far: 0.007027273532003164
# Total elapsed time: 00h 56m 41s

# %%
best_model = tuner_lstm.get_best_models(num_models=1)[0]
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 12 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# best_lstm_hp = tuner_lstm.get_best_hyperparameters(num_trials=1)[0]

# print("Best units:", best_lstm_hp.get("units"))
# print("Best learning rate:", best_lstm_hp.get("learning_rate"))

# %%
# best_model_lstm= tuner_lstm.hypermodel.build(best_lstm_hp)
best_hp = tuner_lstm.get_best_hyperparameters(1)[0]
print(best_hp.values)
# Out:
# {'lstm_units': 32, 'learning_rate': 0.00012589254117941674}

# %%
best_model_lstm= tuner_lstm.hypermodel.build(best_hp)

# %%
best_model_lstm.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 32)                  │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,641 (18.13 KB)
#  Trainable params: 4,641 (18.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = best_model_lstm.fit(
    X_train_seq,
    y_train_seq,
    epochs=50,
    validation_data=(X_val_seq, y_val_seq),
    batch_size=32,
    shuffle=False
)
# Out:
# Epoch 1/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0095 - mae: 0.0761 - val_loss: 0.0069 - val_mae: 0.0662
# Epoch 2/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0094 - mae: 0.0760 - val_loss: 0.0069 - val_mae: 0.0661
# Epoch 3/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0094 - mae: 0.0759 - val_loss: 0.0069 - val_mae: 0.0660
# Epoch 4/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0094 - mae: 0.0759 - val_loss: 0.0069 - val_mae: 0.0659
# Epoch 5/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0094 - mae: 0.0758 - val_loss: 0.0069 - val_mae: 0.0659
# Epoch 6/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0094 - mae: 0.0757 - val_loss: 0.0069 - val_mae: 0.0658
# Epoch 7/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0094 - mae: 0.0756 - val_loss: 0.0069 - val_mae: 0.0657
# Epoch 8/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0094 - mae: 0.0755 - val_loss: 0.0069 - val_mae: 0.0656
# Epoch 9/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0093 - mae: 0.0755 - val_loss: 0.0068 - val_mae: 0.0656
# Epoch 10/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0093 - mae: 0.0754 - val_loss: 0.0068 - val_mae: 0.0655
# Epoch 11/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0093 - mae: 0.0753 - val_loss: 0.0068 - val_mae: 0.0654
# Epoch 12/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0093 - mae: 0.0752 - val_loss: 0.0068 - val_mae: 0.0654
# Epoch 13/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0093 - mae: 0.0752 - val_loss: 0.0068 - val_mae: 0.0653
# Epoch 14/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0093 - mae: 0.0751 - val_loss: 0.0068 - val_mae: 0.0652
# Epoch 15/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - mae: 0.0750 - val_loss: 0.0068 - val_mae: 0.0652
# Epoch 16/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0068 - val_mae: 0.0651
# Epoch 17/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0068 - val_mae: 0.0650
# Epoch 18/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - mae: 0.0748 - val_loss: 0.0068 - val_mae: 0.0650
# Epoch 19/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - mae: 0.0747 - val_loss: 0.0067 - val_mae: 0.0649
# Epoch 20/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0092 - mae: 0.0747 - val_loss: 0.0067 - val_mae: 0.0648
# Epoch 21/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - mae: 0.0746 - val_loss: 0.0067 - val_mae: 0.0648
# Epoch 22/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0091 - mae: 0.0745 - val_loss: 0.0067 - val_mae: 0.0647
# Epoch 23/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0091 - mae: 0.0744 - val_loss: 0.0067 - val_mae: 0.0646
# Epoch 24/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0091 - mae: 0.0744 - val_loss: 0.0067 - val_mae: 0.0646
# Epoch 25/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0091 - mae: 0.0743 - val_loss: 0.0067 - val_mae: 0.0645
# Epoch 26/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0091 - mae: 0.0742 - val_loss: 0.0067 - val_mae: 0.0645
# Epoch 27/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0091 - mae: 0.0742 - val_loss: 0.0067 - val_mae: 0.0644
# Epoch 28/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0091 - mae: 0.0741 - val_loss: 0.0067 - val_mae: 0.0643
# Epoch 29/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0090 - mae: 0.0740 - val_loss: 0.0067 - val_mae: 0.0643
# Epoch 30/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0090 - mae: 0.0740 - val_loss: 0.0066 - val_mae: 0.0642
# Epoch 31/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0090 - mae: 0.0739 - val_loss: 0.0066 - val_mae: 0.0642
# Epoch 32/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0090 - mae: 0.0738 - val_loss: 0.0066 - val_mae: 0.0641
# Epoch 33/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0090 - mae: 0.0738 - val_loss: 0.0066 - val_mae: 0.0641
# Epoch 34/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0090 - mae: 0.0737 - val_loss: 0.0066 - val_mae: 0.0640
# Epoch 35/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0090 - mae: 0.0737 - val_loss: 0.0066 - val_mae: 0.0639
# Epoch 36/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0089 - mae: 0.0736 - val_loss: 0.0066 - val_mae: 0.0639
# Epoch 37/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0089 - mae: 0.0735 - val_loss: 0.0066 - val_mae: 0.0638
# Epoch 38/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0089 - mae: 0.0735 - val_loss: 0.0066 - val_mae: 0.0638
# Epoch 39/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0089 - mae: 0.0734 - val_loss: 0.0066 - val_mae: 0.0637
# Epoch 40/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0089 - mae: 0.0733 - val_loss: 0.0066 - val_mae: 0.0637
# Epoch 41/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0089 - mae: 0.0733 - val_loss: 0.0066 - val_mae: 0.0636
# Epoch 42/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0089 - mae: 0.0732 - val_loss: 0.0066 - val_mae: 0.0636
# Epoch 43/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0089 - mae: 0.0732 - val_loss: 0.0066 - val_mae: 0.0635
# Epoch 44/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0088 - mae: 0.0731 - val_loss: 0.0065 - val_mae: 0.0635
# Epoch 45/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0088 - mae: 0.0731 - val_loss: 0.0065 - val_mae: 0.0634
# Epoch 46/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0088 - mae: 0.0730 - val_loss: 0.0065 - val_mae: 0.0634
# Epoch 47/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0088 - mae: 0.0729 - val_loss: 0.0065 - val_mae: 0.0633
# Epoch 48/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0088 - mae: 0.0729 - val_loss: 0.0065 - val_mae: 0.0633
# Epoch 49/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0088 - mae: 0.0728 - val_loss: 0.0065 - val_mae: 0.0633
# Epoch 50/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0088 - mae: 0.0728 - val_loss: 0.0065 - val_mae: 0.0632

# %%
y_pred_scaled = best_model_lstm.predict(X_test_seq)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test_seq)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y_test_original, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred)
r2 = r2_score(y_test_original, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 1.0918100723568551
# MAE: 0.8326287671172792
# R2: 0.5534629202496957

# %%
# Vẽ biểu đồ so sánh Thực tế vs Dự đoán
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test_original[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("So sánh nhiệt độ thực tế và dự đoán")
plt.show()

# %%
# Vẽ biểu đồ Loss trong quá trình train
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training vs Validation Loss")
plt.show()

# %%
mape = np.mean(np.abs((y_test_original - y_pred) / y_test_original)) * 100
print(f"Sai số phần trăm trung bình (MAPE): {mape:.2f}%")
# Out:
# Sai số phần trăm trung bình (MAPE): 3.18%

# %%
accuracy = 100 - mape
print(f"Độ chính xác (Accuracy): {accuracy:.2f}%")
# Out:
# Độ chính xác (Accuracy): 96.82%

# %%
# best_model.save("best_lstm_model.h5")
