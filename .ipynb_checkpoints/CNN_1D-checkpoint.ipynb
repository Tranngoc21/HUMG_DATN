# %%
import numpy as np
import pandas as pd
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras import layers

# %%
import tensorflow as tf
import random

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
df = pd.read_csv('Data/data_preprocessing.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             Precipitation  Temperature  Relative Humidity  Wind Speed
# Date
# 1985-01-01            0.0        24.12              66.46       26.87
# 1985-01-02            0.0        24.27              66.08       26.60
# 1985-01-03            0.1        25.02              61.42       22.44
# 1985-01-04            0.2        25.26              60.54       22.89
# 1985-01-05            0.0        25.05              59.92       24.88

# %%
# Sắp xếp và kiểm tra dữ liệu
df = df.sort_index()

# kiểm tra liên tục thời gian
print(df.index.to_series().diff().value_counts().head())
# Out:
# Date
# 1 days    12204
# Name: count, dtype: int64

# %%
# Chọn biến đầu vào & mục tiêu
features = ['Precipitation', 'Relative Humidity', 'Wind Speed']
target = 'Temperature'

X = df[features]
y = df[target]

# %%
# Chia tập dữ liệu: 70% train, 15% validation, 15% test
total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)

X_train = X[:train_size]
y_train = y[:train_size]

X_val = X[train_size:train_size + val_size]
y_val = y[train_size:train_size + val_size]

X_test = X[train_size + val_size:]
y_test = y[train_size + val_size:]

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (8543, 3)
# y_train shape: (8543,)
# X_val shape: (1830, 3)
# y_val shape: (1830,)
# X_test shape: (1832, 3)
# y_test shape: (1832,)

# %%
from sklearn.preprocessing import MinMaxScaler
# Chuẩn hóa dữ liệu
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled   = scaler_X.transform(X_val)
X_test_scaled  = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_val_scaled   = scaler_y.transform(y_val.values.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.values.reshape(-1,1))

# %%
# Hàm tạo chuỗi dữ liệu > Dự đoán ngày tiếp theo
def create_sequences(X, y, time_step):
    X_seq, y_seq = [], []
    
    for i in range(len(X) - time_step):
        X_seq.append(X[i:i + time_step])
        y_seq.append(y[i + time_step])
        
    return np.array(X_seq), np.array(y_seq)

# %%
# Xác định time_step = 30 
time_step = 30

X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_scaled, time_step)
X_val_seq, y_val_seq     = create_sequences(X_val_scaled, y_val_scaled, time_step)
X_test_seq, y_test_seq   = create_sequences(X_test_scaled, y_test_scaled, time_step)

# %%
# reshape cho CNN-1D
X_train_seq = X_train_seq.reshape((X_train_seq.shape[0], X_train_seq.shape[1], X_train_seq.shape[2]))
X_val_seq   = X_val_seq.reshape((X_val_seq.shape[0], X_val_seq.shape[1], X_val_seq.shape[2]))

# %%
print(X_train_seq.shape)
print(X_val_seq.shape)
# Out:
# (8513, 30, 3)
# (1800, 30, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense
def build_cnn(hp):

    model = Sequential([
        Input(shape=(X_train_seq.shape[1], X_train_seq.shape[2])),

        Conv1D(
            filters=hp.Int("filters", 32, 128, step=32),
            kernel_size=hp.Choice("kernel_size",[2,3,5]),
            activation='relu'
        ),

        MaxPooling1D(pool_size=2),

        Flatten(),

        Dense(
            units=hp.Int("dense_units",32,128,step=32),
            activation='relu'
        ),

        Dense(1)
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Float("learning_rate",1e-4,1e-2,sampling="log")
        ),
        loss="mse",
        metrics=["mae"]
    )

    return model

# %%
import keras_tuner as kt

tuner_cnn = kt.GridSearch(
    build_cnn,
    objective="val_loss",
    executions_per_trial=1,
    overwrite=True,
    directory="hyperparameter_tuning",
    project_name="cnn_grid_search"
)

# %%
tuner_cnn.search(
    X_train_seq,
    y_train_seq,
    epochs=20,
    validation_data=(X_val_seq, y_val_seq),
    batch_size=32,
    shuffle=False
)
# Out:
# Trial 528 Complete [00h 00m 26s]
# val_loss: 0.009095212444663048
#
# Best val_loss So Far: 0.006450312212109566
# Total elapsed time: 03h 24m 21s

# %%
# best_cnn_hp = tuner_cnn.get_best_hyperparameters(num_trials=1)[0]
# print("Best filters:", best_cnn_hp.get("filters"))
# print("Best kernel size:", best_cnn_hp.get("kernel_size"))
# print("Best dense units:", best_cnn_hp.get("dense_units"))
# print("Best learning rate:", best_cnn_hp.get("learning_rate"))
best_model = tuner_cnn.get_best_models(num_models=1)[0]
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# best_model_cnn= tuner_cnn.hypermodel.build(best_cnn_hp)
best_cnn_hp = tuner_cnn.get_best_hyperparameters(1)[0]
print(best_cnn_hp.values)
# Out:
# {'filters': 96, 'kernel_size': 3, 'dense_units': 96, 'learning_rate': 0.000316227766016838}

# %%
best_model_cnn = tuner_cnn.hypermodel.build(best_cnn_hp)

# %%
best_model_cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)                    │ (None, 28, 96)              │             960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 14, 96)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1344)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 96)                  │         129,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              97 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 130,177 (508.50 KB)
#  Trainable params: 130,177 (508.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

# %%
history = best_model_cnn.fit(
    X_train_seq,
    y_train_seq,
    epochs=50,
    validation_data=(X_val_seq, y_val_seq),
    batch_size=32,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0426 - mae: 0.1655 - val_loss: 0.0241 - val_mae: 0.1228
# Epoch 2/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0297 - mae: 0.1394 - val_loss: 0.0181 - val_mae: 0.1079
# Epoch 3/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0212 - mae: 0.1172 - val_loss: 0.0125 - val_mae: 0.0903
# Epoch 4/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0154 - mae: 0.0987 - val_loss: 0.0095 - val_mae: 0.0780
# Epoch 5/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0127 - mae: 0.0887 - val_loss: 0.0083 - val_mae: 0.0726
# Epoch 6/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0116 - mae: 0.0846 - val_loss: 0.0078 - val_mae: 0.0697
# Epoch 7/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0110 - mae: 0.0825 - val_loss: 0.0076 - val_mae: 0.0685
# Epoch 8/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0107 - mae: 0.0811 - val_loss: 0.0074 - val_mae: 0.0677
# Epoch 9/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0104 - mae: 0.0801 - val_loss: 0.0073 - val_mae: 0.0670
# Epoch 10/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0102 - mae: 0.0792 - val_loss: 0.0072 - val_mae: 0.0666
# Epoch 11/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0100 - mae: 0.0784 - val_loss: 0.0071 - val_mae: 0.0664
# Epoch 12/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0098 - mae: 0.0778 - val_loss: 0.0070 - val_mae: 0.0660
# Epoch 13/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0096 - mae: 0.0771 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 14/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0095 - mae: 0.0766 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 15/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0094 - mae: 0.0762 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 16/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0071 - val_mae: 0.0660
# Epoch 17/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0091 - mae: 0.0751 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 18/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0090 - mae: 0.0747 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 19/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0090 - mae: 0.0744 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 20/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0089 - mae: 0.0741 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 21/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0088 - mae: 0.0737 - val_loss: 0.0071 - val_mae: 0.0661
# Epoch 22/50
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0087 - mae: 0.0734 - val_loss: 0.0071 - val_mae: 0.0661

# %%
y_pred_scaled = best_model_cnn.predict(X_test_seq)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_original = scaler_y.inverse_transform(y_test_seq)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

mse = mean_squared_error(y_test_original, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_original, y_pred)
r2 = r2_score(y_test_original, y_pred)

print("RMSE:", rmse)
print("MAE:", mae)
print("R2:", r2)
# Out:
# RMSE: 1.1517674147311125
# MAE: 0.8867612710036131
# R2: 0.5030726389596395

# %%
# Vẽ biểu đồ so sánh Thực tế vs Dự đoán
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(y_test_original[:200], label="Actual")
plt.plot(y_pred[:200], label="Predicted")
plt.legend()
plt.title("So sánh nhiệt độ thực tế và dự đoán")
plt.show()

# %%
# Vẽ biểu đồ Loss trong quá trình train
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.title("Training vs Validation Loss")
plt.show()

# %%
mape = np.mean(np.abs((y_test_original - y_pred) / y_test_original)) * 100
print(f"Sai số phần trăm trung bình (MAPE): {mape:.2f}%")
# Out:
# Sai số phần trăm trung bình (MAPE): 3.37%

# %%
accuracy = 100 - mape
print(f"Độ chính xác (Accuracy): {accuracy:.2f}%")
# Out:
# Độ chính xác (Accuracy): 96.63%

# %%
best_model_cnn.save("module_cnn_1d.keras")
